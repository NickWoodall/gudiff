# %%
import pyrosetta
import pyrosetta.rosetta as rosetta
import random
vdw_weight = {0: 3.0, 1: 5.0, 2: 10.0}
rsr_dist_weight = {0: 3.0, 1: 2.0, 3: 1.0}
rsr_orient_weight = {0: 1.0, 1: 1.0, 3: 0.5}

# %%
import numpy as np
# data_path_str  = 'data/h4_ca_coords.npz'
# test_limit = 1028
# rr = np.load(data_path_str)
# ca_coords = [rr[f] for f in rr.files][0][:test_limit,:,:3]
# ca_coords.shape

# getting N-Ca, Ca-C vectors to add as typeI features
#apa = apart helices for test/train split
#tog = together helices for test/train split
apa_path_str  = 'data/h4_apa_coords.npz'
tog_path_str  = 'data/h4_tog_coords.npz'

#grab the first 3 atoms which are N,CA,C
test_limit = 1028
rr = np.load(apa_path_str)
coords_apa = [rr[f] for f in rr.files][0][:test_limit,:,:3]

rr = np.load(tog_path_str)
coords_tog = [rr[f] for f in rr.files][0][:test_limit,:,:3]

# %%
 pyrosetta.init('')
# Out:
# PyRosetta-4 2023 [Rosetta PyRosetta4.conda.linux.cxx11thread.serialization.CentOS.python38.Release 2023.20+release.dbbb5449bf9583f5b8d8f4151636d460bbeedba3 2023-05-16T11:06:33] retrieved from: http://www.pyrosetta.org
# (C) Copyright Rosetta Commons Member Institutions. Created in JHU by Sergey Lyskov and PyRosetta Team.
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# core.init: Rosetta version: PyRosetta4.conda.linux.cxx11thread.serialization.CentOS.python38.Release r349 2023.20+release.dbbb544 dbbb5449bf9583f5b8d8f4151636d460bbeedba3 http://www.pyrosetta.org 2023-05-16T11:06:33
# core.init: command: PyRosetta -database /home/nwoodall/miniconda3/envs/hdes/lib/python3.8/site-packages/pyrosetta/database
# basic.random.init_random_generator: 'RNG device' seed mode, using '/dev/urandom', seed=460073725 seed_offset=0 real_seed=460073725 thread_index=0
# basic.random.init_random_generator: RandomGenerator:init: Normal mode, seed=460073725 RG_type=mt19937

# %%
sf = pyrosetta.ScoreFunction()
sf.add_weights_from_file(str('Rosetta_Min/scorefxn.wts'))

sf1 = pyrosetta.ScoreFunction()
sf1.add_weights_from_file(str('Rosetta_Min/scorefxn1.wts'))

sf_vdw = pyrosetta.ScoreFunction()
sf_vdw.add_weights_from_file(str('Rosetta_Min/scorefxn_vdw.wts'))

sf_cart = pyrosetta.ScoreFunction()
sf_cart.add_weights_from_file(str('Rosetta_Min/scorefxn_cart.wts'))

mmap = pyrosetta.MoveMap()
mmap.set_bb(True)
mmap.set_chi(False)
mmap.set_jump(True)

min_mover1 = MinMover(mmap, sf1, 'lbfgs_armijo_nonmonotone', 0.001, True)
min_mover1.max_iter(1000)

min_mover_vdw = MinMover(mmap, sf_vdw, 'lbfgs_armijo_nonmonotone', 0.001, True)
min_mover_vdw.max_iter(500)

min_mover_cart = MinMover(mmap, sf_cart, 'lbfgs_armijo_nonmonotone', 0.000001, True)
min_mover_cart.max_iter(300)
min_mover_cart.cartesian(True)
# Out:
# basic.io.database: Database file opened: scoring/score_functions/centroid_smooth/cen_hb_params.txt
# core.scoring.ramachandran: shapovalov_lib::shap_rama_smooth_level of 4( aka highest_smooth ) got activated.
# basic.io.database: Database file opened: scoring/score_functions/rama/shapovalov/kappa25/all.ramaProb
# basic.io.database: Database file opened: scoring/score_functions/rama/flat/avg_L_rama.dat
# core.scoring.ramachandran: Reading custom Ramachandran table from scoring/score_functions/rama/flat/avg_L_rama.dat.
# basic.io.database: Database file opened: scoring/score_functions/rama/flat/sym_all_rama.dat
# core.scoring.ramachandran: Reading custom Ramachandran table from scoring/score_functions/rama/flat/sym_all_rama.dat.
# basic.io.database: Database file opened: scoring/score_functions/rama/flat/sym_G_rama.dat
# core.scoring.ramachandran: Reading custom Ramachandran table from scoring/score_functions/rama/flat/sym_G_rama.dat.
# basic.io.database: Database file opened: scoring/score_functions/rama/flat/sym_P_rama.dat
# core.scoring.ramachandran: Reading custom Ramachandran table from scoring/score_functions/rama/flat/sym_P_rama.dat.
# basic.io.database: Database file opened: scoring/score_functions/rama/flat/avg_L_rama_str.dat
# core.scoring.ramachandran: Reading custom Ramachandran table from scoring/score_functions/rama/flat/avg_L_rama_str.dat.
# basic.io.database: Database file opened: scoring/score_functions/rama/flat/sym_all_rama_str.dat
# core.scoring.ramachandran: Reading custom Ramachandran table from scoring/score_functions/rama/flat/sym_all_rama_str.dat.
# basic.io.database: Database file opened: scoring/score_functions/rama/flat/sym_G_rama_str.dat
# core.scoring.ramachandran: Reading custom Ramachandran table from scoring/score_functions/rama/flat/sym_G_rama_str.dat.
# basic.io.database: Database file opened: scoring/score_functions/rama/flat/sym_P_rama_str.dat
# core.scoring.ramachandran: Reading custom Ramachandran table from scoring/score_functions/rama/flat/sym_P_rama_str.dat.
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.all.txt
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.gly.txt
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.pro.txt
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.valile.txt
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/HBPoly1D.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/HBFadeIntervals.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/HBEval.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/DonStrength.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/AccStrength.csv
# core.energy_methods.CartesianBondedEnergy: Initializing IdealParametersDatabase with default Ks=300 , 80 , 80 , 10 , 80
# basic.io.database: Database file opened: scoring/score_functions/bondlength_bondangle/default-lengths.txt
# core.energy_methods.CartesianBondedEnergy: Read 759 bb-independent lengths.
# basic.io.database: Database file opened: scoring/score_functions/bondlength_bondangle/default-angles.txt
# core.energy_methods.CartesianBondedEnergy: Read 1434 bb-independent angles.
# basic.io.database: Database file opened: scoring/score_functions/bondlength_bondangle/default-torsions.txt
# core.energy_methods.CartesianBondedEnergy: Read 1 bb-independent torsions.
# basic.io.database: Database file opened: scoring/score_functions/bondlength_bondangle/default-improper.txt
# core.energy_methods.CartesianBondedEnergy: Read 529 bb-independent improper tors.

# %%
def set_random_dihedral(pose,virt=True):
    nres = pose.total_residue()
    #do not operate on appended virtual residue
    if virt:
        nres -= 1
    for i in range(1, nres+1):
        phi,psi=random_dihedral()
        pose.set_phi(i,phi)
        pose.set_psi(i,psi)
        pose.set_omega(i,180)

    return(pose)


#pick phi/psi randomly from:
#-140  153 180 0.135 B
# -72  145 180 0.155 B
#-122  117 180 0.073 B
# -82  -14 180 0.122 A
# -61  -41 180 0.497 A
#  57   39 180 0.018 L
def random_dihedral():
    phi=0
    psi=0
    r=random.random()
    if(r<=0.135):
        phi=-140
        psi=153
    elif(r>0.135 and r<=0.29):
        phi=-72
        psi=145
    elif(r>0.29 and r<=0.363):
        phi=-122
        psi=117
    elif(r>0.363 and r<=0.485):
        phi=-82
        psi=-14
    elif(r>0.485 and r<=0.982):
        phi=-61
        psi=-41
    else:
        phi=57
        psi=39
    return(phi, psi)

def remove_clash(scorefxn, mover, pose):
    for _ in range(0, 5):
        if float(scorefxn(pose)) < 10:
            break
        mover.apply(pose)

# %%
def rv(coord_data):
    return pyrosetta.rosetta.numeric.xyzVector_double_t(coord_data[0],coord_data[1],coord_data[2])


def load_con(pose, xyz_coords, dist_std = 5):
    
    length = len(pose.sequence())
    vr = pyrosetta.AtomID(pose.residue(length).atom_index('X'),length)

    # dictionary to store Rosetta restraints
    rst = []
    
    har = rosetta.core.scoring.func.HarmonicFunc(0, dist_std)
    
    for i in range(1,len(xyz_coords)+1):

        xyz_N = rv(xyz_coords[i-1,0])
        idn = pyrosetta.AtomID(pose.residue(i).atom_index("N"),i) # CA idx for residue i
        rst.append(pyrosetta.rosetta.core.scoring.constraints.CoordinateConstraint(idn, vr, xyz_N, har))
        
        xyz_CA = rv(xyz_coords[i-1,1])
        idca = pyrosetta.AtomID(pose.residue(i).atom_index("CA"),i) # CA idx for residue i
        rst.append(pyrosetta.rosetta.core.scoring.constraints.CoordinateConstraint(idca, vr, xyz_CA, har)) 
        
        xyz_C = rv(xyz_coords[i-1,2])
        idc = pyrosetta.AtomID(pose.residue(i).atom_index("C"),i) # CA idx for residue i
        rst.append(pyrosetta.rosetta.core.scoring.constraints.CoordinateConstraint(idc, vr, xyz_C, har))
        
    return rst

def load_con_single(pose, xyz_coords, i, dist_std = 5):
    
    length = len(pose.sequence())
    vr = pyrosetta.AtomID(pose.residue(length).atom_index('X'),length)

    # dictionary to store Rosetta restraints
    rst = []
    
    har = rosetta.core.scoring.func.HarmonicFunc(0, dist_std)

    xyz_N = rv(xyz_coords[i-1,0])
    idn = pyrosetta.AtomID(pose.residue(i).atom_index("N"),i) # CA idx for residue i
    rst.append(pyrosetta.rosetta.core.scoring.constraints.CoordinateConstraint(idn, vr, xyz_N, har))

    xyz_CA = rv(xyz_coords[i-1,1])
    idca = pyrosetta.AtomID(pose.residue(i).atom_index("CA"),i) # CA idx for residue i
    rst.append(pyrosetta.rosetta.core.scoring.constraints.CoordinateConstraint(idca, vr, xyz_CA, har)) 

    xyz_C = rv(xyz_coords[i-1,2])
    idc = pyrosetta.AtomID(pose.residue(i).atom_index("C"),i) # CA idx for residue i
    rst.append(pyrosetta.rosetta.core.scoring.constraints.CoordinateConstraint(idc, vr, xyz_C, har))
        
    return rst

def add_rst(pose,rst):

    cset = pyrosetta.rosetta.core.scoring.constraints.ConstraintSet()
    [cset.add_constraint(a) for a in rst]

    # add to pose
    constraints = pyrosetta.rosetta.protocols.constraint_movers.ConstraintSetMover()
    constraints.constraint_set(cset)
    constraints.add_constraints(True)
    constraints.apply(pose)

# %%
pose0 = pyrosetta.pose_from_sequence('A'*65, 'centroid')
pose0.translate(np.array([-1.4581,0,0])) #move to origin
# Out:
# core.chemical.GlobalResidueTypeSet: Finished initializing centroid residue type set.  Created 69 residue types
# core.chemical.GlobalResidueTypeSet: Total time to initialize 0.024176 seconds.

# %%
test_coord = coords_tog[0,:,:3]

# %%
test_coord = coords_tog[0,:,:3]

# %%
pose0 = pyrosetta.pose_from_sequence('A'*65, 'centroid')
pose0.dump_pdb('output/before.pdb')

pyrosetta.rosetta.core.pose.addVirtualResAsRoot(pose0)
set_random_dihedral(pose0)
remove_clash(sf_vdw, min_mover_vdw, pose0)
pose0.dump_pdb('output/after.pdb')
tf = pyrosetta.rosetta.core.pack.task.TaskFactory()
tf.push_back(pyrosetta.rosetta.core.pack.task.operation.InitializeFromCommandline())
tf.push_back(pyrosetta.rosetta.core.pack.task.operation.IncludeCurrent())

indices_to_design = None

#rst1 = load_con(pose0,test_coord,d)

# %%
Emin = 999999
for i in range(1,65):
    
    
    rst1 = load_con_single(pose0,test_coord,i, dist_std = 0.3)
    # define repeat_mover here!! (update vdw weights: weak (1.0) -> strong (10.0)
    sf.set_weight(rosetta.core.scoring.vdw, vdw_weight.setdefault(0, 0.1))
#     sf.set_weight(rosetta.core.scoring.atom_pair_constraint, rsr_dist_weight.setdefault(run, 1.0))
#     sf.set_weight(rosetta.core.scoring.dihedral_constraint, rsr_orient_weight.setdefault(run, 0.5))
#     sf.set_weight(rosetta.core.scoring.angle_constraint, rsr_orient_weight.setdefault(run, 0.5))
    sf.set_weight(rosetta.core.scoring.coordinate_constraint, rsr_orient_weight.setdefault(0, 10.0))
    
   


    min_mover = MinMover(mmap, sf, 'lbfgs_armijo_nonmonotone', 0.001, True)
    min_mover.max_iter(1000)

    repeat_mover = pyrosetta.RepeatMover(min_mover, 2)

#     if run > 0:
#         L = len(pose.sequence()) -1 #ignore appended virtual atom
#         # diversify backbone
#         dphi = np.random.uniform(-10,10,L)
#         dpsi = np.random.uniform(-10,10,L)

# #             if indices_to_design:
# #                 for i in indices_to_design:
# #                     i = int(i)
# #                     pose.set_phi(i,pose.phi(i)+dphi[i-1])
# #                     pose.set_psi(i,pose.psi(i)+dpsi[i-1])
# #             else:
#         for i in range(1,L+1):
#             pose.set_phi(i,pose.phi(i)+dphi[i-1])
#             pose.set_psi(i,pose.psi(i)+dpsi[i-1])

#         # remove clashes
#         remove_clash(sf_vdw, min_mover_vdw, pose)

    # short
    add_rst(pose0, rst1)
    repeat_mover.apply(pose0)
    remove_clash(sf_vdw, min_mover1, pose0)
    min_mover_cart.apply(pose0)

#     # medium
#     add_rst(pose, rst)
#     repeat_mover.apply(pose)
#     remove_clash(sf_vdw, min_mover1, pose)
#     min_mover_cart.apply(pose)

#     # long
#     add_rst(pose, rst)
#     repeat_mover.apply(pose)
#     remove_clash(sf_vdw, min_mover1, pose)
#     min_mover_cart.apply(pose)

    # check whether energy has decreased
#     E = sf_cart(pose)
#     if E < Emin:
#         Emin = E
#     pose0.assign(pose)

#     pose0.remove_constraints()
    pose0.dump_pdb(f'output/structure_before_design-{i}.pdb')
# Out:
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.energy_methods.CartesianBondedEnergy: Adding undefined angle VRT: X,ORIG,Y to DB with theta0 = 1.5708 , Ktheta = 80
# core.energy_methods.CartesianBondedEnergy: Adding undefined length VRT: ORIG,X, to DB with d0 = 1 , Kd = 300
# core.energy_methods.CartesianBondedEnergy: Adding undefined length VRT: ORIG,Y, to DB with d0 = 1 , Kd = 300
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.optimization.LineMinimizer: Inaccurate G in step= 7.45058e-09 Deriv= -109.723 Finite Diff= 5.32515e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 4.2623e-07 Deriv= -320.4 Finite Diff= 9.30843e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#125
# core.optimization.LineMinimizer: Inaccurate G in step= 9.53674e-09 Deriv= -318.498 Finite Diff= 4.16027e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 4.275e-07 Deriv= -318.498 Finite Diff= 9.28076e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#3
# core.optimization.LineMinimizer: Inaccurate G in step= 3.8147e-08 Deriv= -42.6902 Finite Diff= 1.04007e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 1.16769e-06 Deriv= -42.6902 Finite Diff= 3.39778e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#1
# core.optimization.LineMinimizer: Inaccurate G in step= 3.8147e-08 Deriv= -42.6902 Finite Diff= 1.04007e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 1.16769e-06 Deriv= -42.6902 Finite Diff= 3.39778e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#1
# core.optimization.LineMinimizer: Inaccurate G in step= 3.8147e-08 Deriv= -42.6902 Finite Diff= 1.04007e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 1.16769e-06 Deriv= -42.6902 Finite Diff= 3.39778e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#1
# core.optimization.LineMinimizer: Inaccurate G in step= 3.8147e-08 Deriv= -42.6902 Finite Diff= 1.04007e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 1.16769e-06 Deriv= -42.6902 Finite Diff= 3.39778e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#1
# core.optimization.LineMinimizer: Inaccurate G in step= 3.8147e-08 Deriv= -42.6902 Finite Diff= 1.04007e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 1.16769e-06 Deriv= -42.6902 Finite Diff= 3.39778e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#1
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.optimization.LineMinimizer: Inaccurate G in step= 3.72529e-09 Deriv= -196.281 Finite Diff= 4.88099e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 1.8917e-07 Deriv= -1626.58 Finite Diff= 9.61189e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#275
# core.optimization.LineMinimizer: Inaccurate G in step= 9.53674e-09 Deriv= -1448.01 Finite Diff= 1.90663e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 2.00495e-07 Deriv= -1448.01 Finite Diff= 9.06894e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#5
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.optimization.LineMinimizer: Inaccurate G in step= 3.72529e-09 Deriv= -157.481 Finite Diff= 7.92039e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 3.17284e-09 Deriv= -570.123 Finite Diff= 9.29471e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 6.38463e-07 Deriv= -142.793 Finite Diff= 4.61899e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#146
# core.optimization.LineMinimizer: Inaccurate G in step= 3.8147e-08 Deriv= -142.811 Finite Diff= 7.73079e+08
# core.optimization.LineMinimizer: Inaccurate G in step= 6.38424e-07 Deriv= -142.811 Finite Diff= 4.61927e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#1
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.optimization.LineMinimizer: Inaccurate G in step= 7.45058e-09 Deriv= -423.91 Finite Diff= 2.02917e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 4.57004e-09 Deriv= -200.347 Finite Diff= 3.30526e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 2.73516e-07 Deriv= -778.062 Finite Diff= 5.52251e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#430
# core.optimization.LineMinimizer: Inaccurate G in step= 3.8147e-08 Deriv= -805.444 Finite Diff= 3.95972e+08
# core.optimization.LineMinimizer: Inaccurate G in step= 2.68827e-07 Deriv= -805.444 Finite Diff= 5.61884e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#1
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 1000 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.optimization.LineMinimizer: Inaccurate G in step= 3.72529e-09 Deriv= -399.272 Finite Diff= 4.10612e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 7.2777e-09 Deriv= -237.15 Finite Diff= 2.1011e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 1.94362e-07 Deriv= -1540.84 Finite Diff= 7.8672e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#222
# core.optimization.LineMinimizer: Inaccurate G in step= 3.8147e-08 Deriv= -1598.08 Finite Diff= 4.00847e+08
# core.optimization.LineMinimizer: Inaccurate G in step= 1.90849e-07 Deriv= -1598.08 Finite Diff= 8.01201e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#1
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.optimization.LineMinimizer: Inaccurate G in step= 7.45058e-09 Deriv= -543.912 Finite Diff= 5.87499e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 8.51038e-08 Deriv= -8036.79 Finite Diff= 5.1433e+08
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#243
# core.optimization.LineMinimizer: Inaccurate G in step= 3.8147e-08 Deriv= -57151.5 Finite Diff= 1.1474e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 3.19136e-08 Deriv= -57151.5 Finite Diff= 1.37152e+09
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#1
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 1000 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.optimization.LineMinimizer: Inaccurate G in step= 3.72529e-09 Deriv= -59.6879 Finite Diff= 7.65274e+09
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 1000 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 1000 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.optimization.LineMinimizer: Inaccurate G in step= 7.45058e-09 Deriv= -1850.16 Finite Diff= 3.63448e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 8.25084e-09 Deriv= -240.85 Finite Diff= 3.28201e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 6.73396e-09 Deriv= -264.273 Finite Diff= 4.0199e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 9.73308e-09 Deriv= -132.891 Finite Diff= 2.78107e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 5.89901e-07 Deriv= -167.272 Finite Diff= 4.58862e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#383
# core.optimization.LineMinimizer: Inaccurate G in step= 4.76837e-09 Deriv= -158.533 Finite Diff= 5.67666e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 6.05941e-07 Deriv= -158.533 Finite Diff= 4.46715e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#2
# core.optimization.LineMinimizer: Inaccurate G in step= 3.8147e-08 Deriv= -32.5314 Finite Diff= 7.09582e+08
# core.optimization.LineMinimizer: Inaccurate G in step= 1.33764e-06 Deriv= -32.5314 Finite Diff= 2.02359e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#1
# core.optimization.LineMinimizer: Inaccurate G in step= 3.8147e-08 Deriv= -32.5314 Finite Diff= 7.09582e+08
# core.optimization.LineMinimizer: Inaccurate G in step= 1.33764e-06 Deriv= -32.5314 Finite Diff= 2.02359e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#1
# core.optimization.LineMinimizer: Inaccurate G in step= 3.8147e-08 Deriv= -32.5314 Finite Diff= 7.09582e+08
# core.optimization.LineMinimizer: Inaccurate G in step= 1.33764e-06 Deriv= -32.5314 Finite Diff= 2.02359e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#1
# core.optimization.LineMinimizer: Inaccurate G in step= 3.8147e-08 Deriv= -32.5314 Finite Diff= 7.09582e+08
# core.optimization.LineMinimizer: Inaccurate G in step= 1.33764e-06 Deriv= -32.5314 Finite Diff= 2.02359e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#1
# core.optimization.LineMinimizer: Inaccurate G in step= 3.8147e-08 Deriv= -32.5314 Finite Diff= 7.09582e+08
# core.optimization.LineMinimizer: Inaccurate G in step= 1.33764e-06 Deriv= -32.5314 Finite Diff= 2.02359e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#1
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.optimization.LineMinimizer: Inaccurate G in step= 7.45058e-09 Deriv= -158.644 Finite Diff= 4.12811e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 1.56226e-07 Deriv= -2384.92 Finite Diff= 1.96871e+08
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#257
# core.optimization.LineMinimizer: Inaccurate G in step= 3.8147e-08 Deriv= -8942.79 Finite Diff= 8.06263e+08
# core.optimization.LineMinimizer: Inaccurate G in step= 8.06777e-08 Deriv= -8942.79 Finite Diff= 3.81222e+08
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#1
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.optimization.LineMinimizer: Inaccurate G in step= 7.45058e-09 Deriv= -1260.03 Finite Diff= 6.69386e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 8.54486e-09 Deriv= -350.194 Finite Diff= 5.85475e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 1.0444e-07 Deriv= -5336.42 Finite Diff= 4.79008e+08
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#209
# core.optimization.LineMinimizer: Inaccurate G in step= 3.8147e-08 Deriv= -4848.5 Finite Diff= 1.31145e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 1.09569e-07 Deriv= -4848.5 Finite Diff= 4.56585e+08
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#1
# core.optimization.LineMinimizer: Inaccurate G in step= 4.76837e-09 Deriv= -12793.6 Finite Diff= 1.05069e+10
# core.optimization.LineMinimizer: Inaccurate G in step= 3.24118e-09 Deriv= -584.819 Finite Diff= 1.55135e+10
# core.optimization.LineMinimizer: Inaccurate G in step= 1.19814e-06 Deriv= -40.5479 Finite Diff= 4.1967e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#30
# core.optimization.LineMinimizer: Inaccurate G in step= 3.8147e-08 Deriv= -40.5479 Finite Diff= 1.31812e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 1.19814e-06 Deriv= -40.5479 Finite Diff= 4.1967e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#1
# core.optimization.LineMinimizer: Inaccurate G in step= 3.8147e-08 Deriv= -40.5479 Finite Diff= 1.31812e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 1.19814e-06 Deriv= -40.5479 Finite Diff= 4.1967e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#1
# core.optimization.LineMinimizer: Inaccurate G in step= 3.8147e-08 Deriv= -40.5479 Finite Diff= 1.31812e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 1.19814e-06 Deriv= -40.5479 Finite Diff= 4.1967e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#1
# core.optimization.LineMinimizer: Inaccurate G in step= 3.8147e-08 Deriv= -40.5479 Finite Diff= 1.31812e+09
# core.optimization.LineMinimizer: Inaccurate G in step= 1.19814e-06 Deriv= -40.5479 Finite Diff= 4.1967e+07
# core.optimization.Minimizer: Line search failed even after resetting Hessian; aborting at iter#1
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
# core.energy_methods.CartesianBondedEnergy: Creating new peptide-bonded energy container (66)
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 300 EXCEEDED, BUT FUNC NOT CONVERGED!
